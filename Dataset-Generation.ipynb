# %%
import random
import networkx as nx
import osmnx as ox
import matplotlib.pyplot as plt
import pandas as pd
from geopy.distance import geodesic
import requests
import json
import uuid
import os
from datetime import datetime
import folium
from folium.plugins import AntPath
from collections import defaultdict

# %%
# ===================== CONFIGURATION =====================
config = {
    "n_users": 100,  # Number of users (each user gets a distinct graph)
    "country_code": "FR",  # Country code for city selection
    "username": "",  # Geonames API username
    "output_base_dir": "Generated_Data"  # Base directory for saving data
}

# Generate timestamped output directory
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
output_dir = os.path.join(config["output_base_dir"], f"Data_For_{timestamp}")

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)
print(f"✅ Output directory created: {output_dir}")

# Load the sensitive POI categories from a JSON file
with open("sensitive_poi_categories.json", "r") as file:
    sensitive_poi_categories = json.load(file)
# Out:
# ✅ Output directory created: Generated_Data/Data_For_2025-03-18_11-31-36

# %%
def get_random_cities_geonames(country_code, username, n_users):
    """
    Fetches `n_users` random city names from GeoNames API for a given country,
    excluding the city 'Gustavia'.

    Parameters:
        country_code (str): The country ISO code (e.g., "FR" for France).
        username (str): GeoNames API username (requires a free account).
        n_users (int): Number of random cities to return.

    Returns:
        list: A list of `n_users` unique city names (or fewer if unavailable).
    """
    max_results = n_users
    url = f"https://secure.geonames.org/searchJSON?country={country_code}&featureClass=P&maxRows={max_results}&username={username}"

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()

        if "geonames" not in data or not isinstance(data["geonames"], list):
            print("⚠️ Warning: Unexpected response format from GeoNames API.")
            return []

        # Extract and filter city names (exclude 'Gustavia')
        cities = [place["name"] for place in data["geonames"] if "name" in place and place["name"].lower() != "gustavia" and place["name"].lower() != "marigot"]

        # Shuffle and select `n_users` unique cities
        random.shuffle(cities)
        return cities[:n_users] if cities else []

    except requests.exceptions.RequestException as e:
        print(f"❌ Error fetching cities from GeoNames: {e}")
        return []

# %%
def get_random_villages_geonames(country_code, username, n=5):
    url = f"https://secure.geonames.org/searchJSON?country={country_code}&featureClass=P&featureCode=PPL&maxRows=1000&username={username}"
    
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        villages = [place["name"] for place in data["geonames"] if "name" in place]

        # Mélanger et sélectionner aléatoirement
        random.shuffle(villages)
        
        return villages[:n] if villages else []
    
    return []

# %%
def plot_graph_on_map(G, city, user_id):
    """
    Displays the user's POI graph on a real map using Folium.

    Parameters:
        G (networkx.DiGraph): The directed graph of POIs.
        city (str): The city where the graph is generated.
        user_id (str): Unique identifier of the user.
        output_dir (str): Directory to save the map.

    Returns:
        folium.Map: The interactive map object.
    """
    if not G.nodes:
        print(f"⚠️ No nodes in graph for {user_id}. Skipping map generation.")
        return None
    # Get node positions (latitude, longitude)
    pos = nx.get_node_attributes(G, "pos")
    categories = nx.get_node_attributes(G, "category")

    # Get the map center (average lat/lon)
    avg_lat = sum([p[1] for p in pos.values()]) / len(pos)
    avg_lon = sum([p[0] for p in pos.values()]) / len(pos)

    # Create a Folium map centered at the average location
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=14, control_scale=True)

# Association des valeurs à leurs couleurs
    value_color_map = {}

    # Define category colors
    category_colors = {
        "healthcare": "red",
        "religious_sites": "blue",
        "education": "green",
        "finance": "purple",
        "social_services": "orange",
        "residential": "cyan",
        "transportation": "magenta",
        "law_enforcement": "brown",
        "government": "black",
        "shopping": "yellow"
    }

    for category, details in sensitive_poi_categories.items():
        color = category_colors.get(category, "gray")
        for value in details["values"]:
            value_color_map[value] = color
    

    # Add POI nodes (markers)
    for node, (lon, lat) in pos.items():
        node_value = nx.get_node_attributes(G, "category").get(node, None)
        color = value_color_map.get(node_value, "gray")
        folium.CircleMarker(
            location=[lat, lon],
            radius=6,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.8,
            popup=f"POI-Category: {node_value}",
        ).add_to(m)

    # Add edges with directional arrows
    for u, v, edge_data in G.edges(data=True):
        coords = [[pos[u][1], pos[u][0]], [pos[v][1], pos[v][0]]]  # Format: [lat, lon]
        # Retrieve weights (list of movement tuples)
        weight_info = edge_data.get("weight", [])
        # Format weight details for popup
        weight_text = "\n".join([
            f"⏳ TS: {w['ts']}, TD: {w['td']}, FS: {w['fs']}, ST: {w['st']} min, DT: {w['dt']} min"
            for w in weight_info
        ]) if weight_info else "No movement data"
        # Use AntPath for animated edges
        AntPath(locations=coords, color="black", delay=800).add_to(m)  # Animated path
        # Static fallback using PolyLine
        folium.PolyLine(locations=coords, color="blue", weight=3, opacity=0.7, popup=weight_text).add_to(m)

    # Ensure the 'map' directory exists within output_dir
    map_dir = os.path.join(output_dir, "map")
    os.makedirs(map_dir, exist_ok=True)  # Create directory if it doesn't exist

    # Save the map
    map_filename = os.path.join(map_dir, f"user_map_{user_id}_from_{city}.html")
    m.save(map_filename)
    print(f"✅ Map for user {user_id} saved: {map_filename}")

    return m

# %%
def generate_multiple_weights():
    """
    Generates multiple weight tuples for an edge, representing movement statistics.
    
    Each weight tuple contains:
    - ts (time segment): Represents different time slots of the day (e.g., morning, afternoon, evening).
    - td (type of day): Categorizes days as either weekdays or weekends.
    - fs (frequency of movement): Counts how often the movement occurs between two locations.
    - st (stay time): The average duration (in minutes) a user stays at the source location before moving.
    - dt (travel duration): The average time (in minutes) it takes to travel from source to destination.

    Steps:
    1. Generate a set of raw weight tuples.
    2. Group the tuples by (ts, td) to aggregate statistics.
    3. Compute the final aggregated values (sum for `fs`, average for `st` and `dt`).

    Returns:
        List of aggregated weight dictionaries.
    """

    num_tuples = random.randint(1, 400)  # Random number of weight tuples per edge

    # Step 1: Generate raw weight tuples
    raw_weights = [
        {
            "ts": random.randint(0, 3),  # Time segment (morning, afternoon, evening, night)
            "td": random.choice([1, 2]),  # Type of day (e.g., 1 = weekday, 2 = weekend)
            "fs": random.randint(1, 1),  # Frequency of movement (number of times this movement occurs)
            "st": random.randint(5, 70),  # Stay time (in minutes) before leaving
            "dt": round(random.uniform(1, 30), 2)  # Travel duration (in minutes)
        }
        for _ in range(num_tuples)
    ]

    # Step 2: Grouping by (ts, td) to aggregate data
    grouped_weights = defaultdict(lambda: {"fs": 0, "st": [], "dt": []})

    for weight in raw_weights:
        key = (weight["ts"], weight["td"])  # Group by (time segment, type of day)
        grouped_weights[key]["fs"] += weight["fs"]  # Sum frequency
        grouped_weights[key]["st"].append(weight["st"])  # Collect stay time for averaging
        grouped_weights[key]["dt"].append(weight["dt"])  # Collect travel duration for averaging

    # Step 3: Compute the final aggregated weight tuples
    aggregated_weights = [
        {
            "ts": ts,
            "td": td,
            "fs": data["fs"],  # Total movement frequency
            "st": round(sum(data["st"]) / len(data["st"]), 2),  # Average stay time at source
            "dt": round(sum(data["dt"]) / len(data["dt"]), 2)  # Average travel duration
        }
        for (ts, td), data in grouped_weights.items()
    ]

    return aggregated_weights

# %%
# ===================== MAIN FUNCTION =====================
def generate_user_graphs(cities, output_dir, max_out_degree=2, max_in_degree=2, radius=2):
    """
    Generates directed POI graphs for users based on random city selections.

    Parameters:
    - cities (list): List of city names to generate graphs for.
    - output_dir (str): Directory to save generated graphs.
    - max_out_degree (int): Maximum outgoing connections per node.
    - max_in_degree (int): Maximum incoming connections per node.
    - radius (int): Connection radius in km.
    """

    for user_idx, city in enumerate(cities):
        user_id = str(uuid.uuid4())  # Unique user identifier
        print(f"Processing user {user_id} in city {city}...")

        # Random number of POIs (between 10 and 30)
        n_poi_per_user = random.randint(5, 20)

        # Initialize POI data
        poi_data = []

        # Fetch POIs
        while len(poi_data) < n_poi_per_user:
            remaining_needed = n_poi_per_user - len(poi_data)
            categories_sampled = random.sample(list(sensitive_poi_categories.keys()), 
                                               min(remaining_needed, len(sensitive_poi_categories)))

            for category in categories_sampled:
                found_poi = None
                for value in sensitive_poi_categories[category]["values"]:
                    try:
                        pois = ox.features_from_place(city, {sensitive_poi_categories[category]["tags"][0]: value})
                        if not pois.empty:
                            found_poi = pois.sample(1)
                            found_poi["category"] = value                            
                            break
                    except:
                        continue

                if found_poi is not None:
                    poi_data.append(found_poi)

                if len(poi_data) >= n_poi_per_user:
                    break

        # Merge POIs into DataFrame
        if not poi_data:
            print(f"No POIs found for user {user_id} in {city}. Skipping...")
            continue

        poi_df = pd.concat(poi_data)
        poi_df = poi_df[["geometry", "category"]].reset_index(drop=True)

        # Extract coordinates
        if not poi_df.empty:
            poi_df["lon"] = poi_df["geometry"].apply(lambda geom: geom.centroid.x)
            poi_df["lat"] = poi_df["geometry"].apply(lambda geom: geom.centroid.y)

        # Build Directed Graph
        G = nx.DiGraph()

        # Add nodes
        for idx, row in poi_df.iterrows():
            G.add_node(idx, pos=(row["lon"], row["lat"]), category=row["category"])

        # Compute distances and possible connections
        edges = []
        for i in range(len(poi_df)):
            for j in range(len(poi_df)):
                if i != j:  # Avoid self-loops
                    dist = geodesic((poi_df.loc[i, "lat"], poi_df.loc[i, "lon"]),
                                    (poi_df.loc[j, "lat"], poi_df.loc[j, "lon"])).km
                    if dist < radius:
                        edges.append((i, j))

        # Shuffle edges to introduce randomness
        random.shuffle(edges)

        # Track degrees
        out_degree = {node: 0 for node in G.nodes}
        in_degree = {node: 0 for node in G.nodes}

        # Add edges while respecting max degree constraints
        for u, v in edges:
            if out_degree[u] < max_out_degree and in_degree[v] < max_in_degree:
                G.add_edge(u, v, weight=generate_multiple_weights())  # Assign multiple weight tuples
                out_degree[u] += 1
                in_degree[v] += 1

        # Ensure Graph Connectivity
        components = list(nx.weakly_connected_components(G))
        if len(components) > 1:
            print(f"User {user_id} graph is disconnected. Connecting components...")
            largest_component = max(components, key=len)
            for component in components:
                if component != largest_component:
                    node_from_largest = random.choice(list(largest_component))
                    node_from_other = random.choice(list(component))
                    G.add_edge(node_from_largest, node_from_other, weight=generate_multiple_weights())

        # Save the graph as JSON
        graph_data = {
            "user_id": user_id,
            "city": city,
            "num_poi": len(G.nodes),
            "nodes": [{"id": n, "category": G.nodes[n]["category"], "position": G.nodes[n]["pos"]} for n in G.nodes],
            "edges": [
                {
                    "source": u,
                    "target": v,
                    "weight": d["weight"]  # This is now a list of weight tuples
                }
                for u, v, d in G.edges(data=True)
            ]
        }

        file_path = f"{output_dir}/user_graph_{user_id}_from_{city}.json"
        with open(file_path, "w") as f:
            json.dump(graph_data, f, indent=4)

        print(f"Graph for user {user_id} with {len(G.nodes)} POIs saved in {file_path}")

        # Plot Directed Graph
         # plt.figure(figsize=(8, 6))
         # pos = nx.get_node_attributes(G, "pos")
         # categories = nx.get_node_attributes(G, "category")
          #colors = {key: plt.cm.tab10(i) for i, key in enumerate(sensitive_poi_categories.keys())}
         # node_colors = [colors[categories[n]] for n in G.nodes]
        
        plot_graph_on_map(G, city, user_id)
        
         # nx.draw(G, pos, with_labels=True, node_size=500, node_color=node_colors, edge_color="gray", arrows=True)
         # plt.title(f"User {user_id} - POI Directed Graph in {city} ({len(G.nodes)} POIs)")
         # plt.show()

# %%
# ===================== EXECUTION =====================
cities = get_random_cities_geonames(config["country_code"], config["username"], config["n_users"])
generate_user_graphs(cities, output_dir)
#villages = get_random_villages_geonames(config["country_code"], config["username"], config["n_users"])
#generate_user_graphs(villages, output_dir)
# Out:
# Processing user b782cbd0-59f7-47d1-b9a0-2d7a08b705e9 in city Paris 19 Buttes-Chaumont...
# Graph for user b782cbd0-59f7-47d1-b9a0-2d7a08b705e9 with 7 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_b782cbd0-59f7-47d1-b9a0-2d7a08b705e9_from_Paris 19 Buttes-Chaumont.json
# ✅ Map for user b782cbd0-59f7-47d1-b9a0-2d7a08b705e9 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_b782cbd0-59f7-47d1-b9a0-2d7a08b705e9_from_Paris 19 Buttes-Chaumont.html
# Processing user b39e1b6e-80b2-4e61-9b16-e187a9e753ec in city Le Mans...
# User b39e1b6e-80b2-4e61-9b16-e187a9e753ec graph is disconnected. Connecting components...
# Graph for user b39e1b6e-80b2-4e61-9b16-e187a9e753ec with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_b39e1b6e-80b2-4e61-9b16-e187a9e753ec_from_Le Mans.json
# ✅ Map for user b39e1b6e-80b2-4e61-9b16-e187a9e753ec saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_b39e1b6e-80b2-4e61-9b16-e187a9e753ec_from_Le Mans.html
# Processing user 84bc2ebc-136f-4251-9127-65560e153074 in city Paris...
# User 84bc2ebc-136f-4251-9127-65560e153074 graph is disconnected. Connecting components...
# Graph for user 84bc2ebc-136f-4251-9127-65560e153074 with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_84bc2ebc-136f-4251-9127-65560e153074_from_Paris.json
# ✅ Map for user 84bc2ebc-136f-4251-9127-65560e153074 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_84bc2ebc-136f-4251-9127-65560e153074_from_Paris.html
# Processing user b92f74d8-3f6a-4bea-b8a2-43b582687f14 in city Le Puy-en-Velay...
# User b92f74d8-3f6a-4bea-b8a2-43b582687f14 graph is disconnected. Connecting components...
# Graph for user b92f74d8-3f6a-4bea-b8a2-43b582687f14 with 13 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_b92f74d8-3f6a-4bea-b8a2-43b582687f14_from_Le Puy-en-Velay.json
# ✅ Map for user b92f74d8-3f6a-4bea-b8a2-43b582687f14 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_b92f74d8-3f6a-4bea-b8a2-43b582687f14_from_Le Puy-en-Velay.html
# Processing user 8210ab8f-7e1f-43f1-8f25-3811b268bc3f in city Aulnay-sous-Bois...
# Graph for user 8210ab8f-7e1f-43f1-8f25-3811b268bc3f with 15 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_8210ab8f-7e1f-43f1-8f25-3811b268bc3f_from_Aulnay-sous-Bois.json
# ✅ Map for user 8210ab8f-7e1f-43f1-8f25-3811b268bc3f saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_8210ab8f-7e1f-43f1-8f25-3811b268bc3f_from_Aulnay-sous-Bois.html
# Processing user 611d083c-95ea-48ec-9a8b-a415f4e97485 in city Brest...
# User 611d083c-95ea-48ec-9a8b-a415f4e97485 graph is disconnected. Connecting components...
# Graph for user 611d083c-95ea-48ec-9a8b-a415f4e97485 with 18 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_611d083c-95ea-48ec-9a8b-a415f4e97485_from_Brest.json
# ✅ Map for user 611d083c-95ea-48ec-9a8b-a415f4e97485 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_611d083c-95ea-48ec-9a8b-a415f4e97485_from_Brest.html
# Processing user c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3 in city Tourcoing...
# User c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3 graph is disconnected. Connecting components...
# Graph for user c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3 with 12 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3_from_Tourcoing.json
# ✅ Map for user c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_c253f4fa-eef2-4c7a-956c-3bc4dfa6a6d3_from_Tourcoing.html
# Processing user 83dcf59b-7b47-4dae-b9dd-bb1d0d8ba7d2 in city Bayeux...
# Graph for user 83dcf59b-7b47-4dae-b9dd-bb1d0d8ba7d2 with 11 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_83dcf59b-7b47-4dae-b9dd-bb1d0d8ba7d2_from_Bayeux.json
# ✅ Map for user 83dcf59b-7b47-4dae-b9dd-bb1d0d8ba7d2 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_83dcf59b-7b47-4dae-b9dd-bb1d0d8ba7d2_from_Bayeux.html
# Processing user 6d83e29e-93f2-4115-be02-cd2dd70e3ff6 in city Beaune...
# Graph for user 6d83e29e-93f2-4115-be02-cd2dd70e3ff6 with 13 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_6d83e29e-93f2-4115-be02-cd2dd70e3ff6_from_Beaune.json
# ✅ Map for user 6d83e29e-93f2-4115-be02-cd2dd70e3ff6 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_6d83e29e-93f2-4115-be02-cd2dd70e3ff6_from_Beaune.html
# Processing user d3433c12-a92a-4db7-89ee-a17b07e884cc in city Caen...
# Graph for user d3433c12-a92a-4db7-89ee-a17b07e884cc with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_d3433c12-a92a-4db7-89ee-a17b07e884cc_from_Caen.json
# ✅ Map for user d3433c12-a92a-4db7-89ee-a17b07e884cc saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_d3433c12-a92a-4db7-89ee-a17b07e884cc_from_Caen.html
# Processing user 9516cb96-e650-4238-9a49-d320a0a47f76 in city Cachan...
# Graph for user 9516cb96-e650-4238-9a49-d320a0a47f76 with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_9516cb96-e650-4238-9a49-d320a0a47f76_from_Cachan.json
# ✅ Map for user 9516cb96-e650-4238-9a49-d320a0a47f76 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_9516cb96-e650-4238-9a49-d320a0a47f76_from_Cachan.html
# Processing user 2ef8e263-147d-4a94-ac93-1f4ce5ebffa5 in city Nantes...
# User 2ef8e263-147d-4a94-ac93-1f4ce5ebffa5 graph is disconnected. Connecting components...
# Graph for user 2ef8e263-147d-4a94-ac93-1f4ce5ebffa5 with 11 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_2ef8e263-147d-4a94-ac93-1f4ce5ebffa5_from_Nantes.json
# ✅ Map for user 2ef8e263-147d-4a94-ac93-1f4ce5ebffa5 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_2ef8e263-147d-4a94-ac93-1f4ce5ebffa5_from_Nantes.html
# Processing user 016e1658-e8ae-407c-abd7-8dc67c98d23e in city Argenteuil...
# Graph for user 016e1658-e8ae-407c-abd7-8dc67c98d23e with 10 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_016e1658-e8ae-407c-abd7-8dc67c98d23e_from_Argenteuil.json
# ✅ Map for user 016e1658-e8ae-407c-abd7-8dc67c98d23e saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_016e1658-e8ae-407c-abd7-8dc67c98d23e_from_Argenteuil.html
# Processing user 29f34c51-2afa-4911-8997-3601b778b260 in city Antibes...
# User 29f34c51-2afa-4911-8997-3601b778b260 graph is disconnected. Connecting components...
# Graph for user 29f34c51-2afa-4911-8997-3601b778b260 with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_29f34c51-2afa-4911-8997-3601b778b260_from_Antibes.json
# ✅ Map for user 29f34c51-2afa-4911-8997-3601b778b260 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_29f34c51-2afa-4911-8997-3601b778b260_from_Antibes.html
# Processing user acdf20e7-3399-4fb0-82df-d6fb584c2759 in city Cagnes-sur-Mer...
# Graph for user acdf20e7-3399-4fb0-82df-d6fb584c2759 with 20 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_acdf20e7-3399-4fb0-82df-d6fb584c2759_from_Cagnes-sur-Mer.json
# ✅ Map for user acdf20e7-3399-4fb0-82df-d6fb584c2759 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_acdf20e7-3399-4fb0-82df-d6fb584c2759_from_Cagnes-sur-Mer.html
# Processing user ffbb7fcb-72b9-4828-b205-5920970ee95f in city Cahors...
# User ffbb7fcb-72b9-4828-b205-5920970ee95f graph is disconnected. Connecting components...
# Graph for user ffbb7fcb-72b9-4828-b205-5920970ee95f with 17 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_ffbb7fcb-72b9-4828-b205-5920970ee95f_from_Cahors.json
# ✅ Map for user ffbb7fcb-72b9-4828-b205-5920970ee95f saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_ffbb7fcb-72b9-4828-b205-5920970ee95f_from_Cahors.html
# Processing user e9f892db-1ec7-49b8-bcf3-ddd284e3067b in city Bastia...
# User e9f892db-1ec7-49b8-bcf3-ddd284e3067b graph is disconnected. Connecting components...
# Graph for user e9f892db-1ec7-49b8-bcf3-ddd284e3067b with 19 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_e9f892db-1ec7-49b8-bcf3-ddd284e3067b_from_Bastia.json
# ✅ Map for user e9f892db-1ec7-49b8-bcf3-ddd284e3067b saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_e9f892db-1ec7-49b8-bcf3-ddd284e3067b_from_Bastia.html
# Processing user 39612792-03ff-4766-81cb-0dff4c0d93e6 in city Aix-en-Provence...
# Graph for user 39612792-03ff-4766-81cb-0dff4c0d93e6 with 5 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_39612792-03ff-4766-81cb-0dff4c0d93e6_from_Aix-en-Provence.json
# ✅ Map for user 39612792-03ff-4766-81cb-0dff4c0d93e6 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_39612792-03ff-4766-81cb-0dff4c0d93e6_from_Aix-en-Provence.html
# Processing user 1a85adfa-2245-460a-acc6-c32557f974fd in city Bagnolet...
# Graph for user 1a85adfa-2245-460a-acc6-c32557f974fd with 10 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_1a85adfa-2245-460a-acc6-c32557f974fd_from_Bagnolet.json
# ✅ Map for user 1a85adfa-2245-460a-acc6-c32557f974fd saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_1a85adfa-2245-460a-acc6-c32557f974fd_from_Bagnolet.html
# Processing user 8aae0743-e588-4bd9-af99-6360bec70885 in city Paris 17 Batignolles-Monceau...
# Graph for user 8aae0743-e588-4bd9-af99-6360bec70885 with 15 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_8aae0743-e588-4bd9-af99-6360bec70885_from_Paris 17 Batignolles-Monceau.json
# ✅ Map for user 8aae0743-e588-4bd9-af99-6360bec70885 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_8aae0743-e588-4bd9-af99-6360bec70885_from_Paris 17 Batignolles-Monceau.html
# Processing user 2e7500a0-5076-40db-9699-87793369296d in city Nice...
# User 2e7500a0-5076-40db-9699-87793369296d graph is disconnected. Connecting components...
# Graph for user 2e7500a0-5076-40db-9699-87793369296d with 16 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_2e7500a0-5076-40db-9699-87793369296d_from_Nice.json
# ✅ Map for user 2e7500a0-5076-40db-9699-87793369296d saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_2e7500a0-5076-40db-9699-87793369296d_from_Nice.html
# Processing user d4cda9f0-9c35-41fa-a363-67b70caa76e7 in city Beauvais...
# User d4cda9f0-9c35-41fa-a363-67b70caa76e7 graph is disconnected. Connecting components...
# Graph for user d4cda9f0-9c35-41fa-a363-67b70caa76e7 with 16 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_d4cda9f0-9c35-41fa-a363-67b70caa76e7_from_Beauvais.json
# ✅ Map for user d4cda9f0-9c35-41fa-a363-67b70caa76e7 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_d4cda9f0-9c35-41fa-a363-67b70caa76e7_from_Beauvais.html
# Processing user ce614a46-b931-44f9-abc0-965c7e06970a in city Bagnols-sur-Cèze...
# Graph for user ce614a46-b931-44f9-abc0-965c7e06970a with 6 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_ce614a46-b931-44f9-abc0-965c7e06970a_from_Bagnols-sur-Cèze.json
# ✅ Map for user ce614a46-b931-44f9-abc0-965c7e06970a saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_ce614a46-b931-44f9-abc0-965c7e06970a_from_Bagnols-sur-Cèze.html
# Processing user 3ceb862d-1f7d-4036-823a-8d133bca363b in city Les Mureaux...
# Graph for user 3ceb862d-1f7d-4036-823a-8d133bca363b with 11 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_3ceb862d-1f7d-4036-823a-8d133bca363b_from_Les Mureaux.json
# ✅ Map for user 3ceb862d-1f7d-4036-823a-8d133bca363b saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_3ceb862d-1f7d-4036-823a-8d133bca363b_from_Les Mureaux.html
# Processing user f6d4340a-3b07-4d00-b7e4-b6693a920b3c in city Marseille...
# User f6d4340a-3b07-4d00-b7e4-b6693a920b3c graph is disconnected. Connecting components...
# Graph for user f6d4340a-3b07-4d00-b7e4-b6693a920b3c with 12 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_f6d4340a-3b07-4d00-b7e4-b6693a920b3c_from_Marseille.json
# ✅ Map for user f6d4340a-3b07-4d00-b7e4-b6693a920b3c saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_f6d4340a-3b07-4d00-b7e4-b6693a920b3c_from_Marseille.html
# Processing user b945866c-dcfa-4fff-9ae4-f5b8dd4e4986 in city Carcassonne...
# User b945866c-dcfa-4fff-9ae4-f5b8dd4e4986 graph is disconnected. Connecting components...
# Graph for user b945866c-dcfa-4fff-9ae4-f5b8dd4e4986 with 13 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_b945866c-dcfa-4fff-9ae4-f5b8dd4e4986_from_Carcassonne.json
# ✅ Map for user b945866c-dcfa-4fff-9ae4-f5b8dd4e4986 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_b945866c-dcfa-4fff-9ae4-f5b8dd4e4986_from_Carcassonne.html
# Processing user f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be in city Saint-Denis...
# User f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be graph is disconnected. Connecting components...
# Graph for user f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be with 12 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be_from_Saint-Denis.json
# ✅ Map for user f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_f52a9c96-dc5f-48bf-b1ed-ffbd0ee6a1be_from_Saint-Denis.html
# Processing user 984c52de-fd5c-4eda-9509-d1a7476b89d7 in city Le Grand-Quevilly...
# Graph for user 984c52de-fd5c-4eda-9509-d1a7476b89d7 with 14 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_984c52de-fd5c-4eda-9509-d1a7476b89d7_from_Le Grand-Quevilly.json
# ✅ Map for user 984c52de-fd5c-4eda-9509-d1a7476b89d7 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_984c52de-fd5c-4eda-9509-d1a7476b89d7_from_Le Grand-Quevilly.html
# Processing user d32cb1bb-dd22-426e-b3e9-559e3c671dbd in city Villeurbanne...
# Graph for user d32cb1bb-dd22-426e-b3e9-559e3c671dbd with 12 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_d32cb1bb-dd22-426e-b3e9-559e3c671dbd_from_Villeurbanne.json
# ✅ Map for user d32cb1bb-dd22-426e-b3e9-559e3c671dbd saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_d32cb1bb-dd22-426e-b3e9-559e3c671dbd_from_Villeurbanne.html
# Processing user 560e9e4e-d24d-4fb0-bbb0-1249810e3675 in city Belfort...
# Graph for user 560e9e4e-d24d-4fb0-bbb0-1249810e3675 with 9 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_560e9e4e-d24d-4fb0-bbb0-1249810e3675_from_Belfort.json
# ✅ Map for user 560e9e4e-d24d-4fb0-bbb0-1249810e3675 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_560e9e4e-d24d-4fb0-bbb0-1249810e3675_from_Belfort.html
# Processing user 2298bde8-bb96-40fa-bf56-2dbe81c81dc4 in city Reims...
# User 2298bde8-bb96-40fa-bf56-2dbe81c81dc4 graph is disconnected. Connecting components...
# Graph for user 2298bde8-bb96-40fa-bf56-2dbe81c81dc4 with 5 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_2298bde8-bb96-40fa-bf56-2dbe81c81dc4_from_Reims.json
# ✅ Map for user 2298bde8-bb96-40fa-bf56-2dbe81c81dc4 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_2298bde8-bb96-40fa-bf56-2dbe81c81dc4_from_Reims.html
# Processing user a1d58da7-b426-4fe8-9429-28244ca868b4 in city Lyon...
# User a1d58da7-b426-4fe8-9429-28244ca868b4 graph is disconnected. Connecting components...
# Graph for user a1d58da7-b426-4fe8-9429-28244ca868b4 with 20 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_a1d58da7-b426-4fe8-9429-28244ca868b4_from_Lyon.json
# ✅ Map for user a1d58da7-b426-4fe8-9429-28244ca868b4 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_a1d58da7-b426-4fe8-9429-28244ca868b4_from_Lyon.html
# Processing user efdd11e1-184f-442f-b283-25c52203feb2 in city Rueil-Malmaison...
# Graph for user efdd11e1-184f-442f-b283-25c52203feb2 with 15 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_efdd11e1-184f-442f-b283-25c52203feb2_from_Rueil-Malmaison.json
# ✅ Map for user efdd11e1-184f-442f-b283-25c52203feb2 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_efdd11e1-184f-442f-b283-25c52203feb2_from_Rueil-Malmaison.html
# Processing user 08765691-39b7-4d1a-b4a8-4550e5aa251e in city Levallois-Perret...
# Graph for user 08765691-39b7-4d1a-b4a8-4550e5aa251e with 12 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_08765691-39b7-4d1a-b4a8-4550e5aa251e_from_Levallois-Perret.json
# ✅ Map for user 08765691-39b7-4d1a-b4a8-4550e5aa251e saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_08765691-39b7-4d1a-b4a8-4550e5aa251e_from_Levallois-Perret.html
# Processing user 9279ab8f-fe41-48a8-a40a-4da95ba77c6e in city Grenoble...
# User 9279ab8f-fe41-48a8-a40a-4da95ba77c6e graph is disconnected. Connecting components...
# Graph for user 9279ab8f-fe41-48a8-a40a-4da95ba77c6e with 7 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_9279ab8f-fe41-48a8-a40a-4da95ba77c6e_from_Grenoble.json
# ✅ Map for user 9279ab8f-fe41-48a8-a40a-4da95ba77c6e saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_9279ab8f-fe41-48a8-a40a-4da95ba77c6e_from_Grenoble.html
# Processing user 54f2a48d-23f1-4f98-ae7f-8417f1b57df9 in city Metz...
# User 54f2a48d-23f1-4f98-ae7f-8417f1b57df9 graph is disconnected. Connecting components...
# Graph for user 54f2a48d-23f1-4f98-ae7f-8417f1b57df9 with 18 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_54f2a48d-23f1-4f98-ae7f-8417f1b57df9_from_Metz.json
# ✅ Map for user 54f2a48d-23f1-4f98-ae7f-8417f1b57df9 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_54f2a48d-23f1-4f98-ae7f-8417f1b57df9_from_Metz.html
# Processing user ad6f16db-c77c-4d2f-b610-b37d33b8a8ea in city Bar-le-Duc...
# Graph for user ad6f16db-c77c-4d2f-b610-b37d33b8a8ea with 18 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_ad6f16db-c77c-4d2f-b610-b37d33b8a8ea_from_Bar-le-Duc.json
# ✅ Map for user ad6f16db-c77c-4d2f-b610-b37d33b8a8ea saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_ad6f16db-c77c-4d2f-b610-b37d33b8a8ea_from_Bar-le-Duc.html
# Processing user 5d9e7add-ee71-47f8-b7f3-49ac77fa961a in city Balma...
# Graph for user 5d9e7add-ee71-47f8-b7f3-49ac77fa961a with 15 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_5d9e7add-ee71-47f8-b7f3-49ac77fa961a_from_Balma.json
# ✅ Map for user 5d9e7add-ee71-47f8-b7f3-49ac77fa961a saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_5d9e7add-ee71-47f8-b7f3-49ac77fa961a_from_Balma.html
# Processing user 52527a28-c654-4e11-a65a-ce931c4e949c in city Blois...
# User 52527a28-c654-4e11-a65a-ce931c4e949c graph is disconnected. Connecting components...
# Graph for user 52527a28-c654-4e11-a65a-ce931c4e949c with 8 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_52527a28-c654-4e11-a65a-ce931c4e949c_from_Blois.json
# ✅ Map for user 52527a28-c654-4e11-a65a-ce931c4e949c saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_52527a28-c654-4e11-a65a-ce931c4e949c_from_Blois.html
# Processing user f994beef-90ed-449b-9c82-8c93df922d81 in city Strasbourg...
# User f994beef-90ed-449b-9c82-8c93df922d81 graph is disconnected. Connecting components...
# Graph for user f994beef-90ed-449b-9c82-8c93df922d81 with 15 POIs saved in Generated_Data/Data_For_2025-03-18_11-31-36/user_graph_f994beef-90ed-449b-9c82-8c93df922d81_from_Strasbourg.json
# ✅ Map for user f994beef-90ed-449b-9c82-8c93df922d81 saved: Generated_Data/Data_For_2025-03-18_11-31-36/map/user_map_f994beef-90ed-449b-9c82-8c93df922d81_from_Strasbourg.html
# Processing user 9ed02981-a9b1-4b39-a3cd-a3016716fa76 in city Marigot...
